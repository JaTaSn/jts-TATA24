# %% [markdown]
# # Word embeddings using gensim

# %% [markdown]
# ## Loading the model

# %%
#first install gensim e.g. via "mamba install gensim"

# %%
import numpy as np
import math

# %%
# load dataset (corpus), wikipedia
import gensim.downloader as api
embedd = api.load('glove-wiki-gigaword-50')

# %%
def restrict_embedd(w2v, restricted_word_set, min_word_length=2):
    new_index_to_key = []
    new_key_to_index = {}
    new_vectors = []
    for ind, word in enumerate(w2v.index_to_key):
        if (not word in restricted_word_set) and len(word) >= min_word_length:
            new_key_to_index[word] = len(new_index_to_key)
            new_index_to_key.append(word)
            new_vectors.append(w2v.vectors[ind])
    w2v.index_to_key = new_index_to_key
    w2v.key_to_index = new_key_to_index
    w2v.vectors = np.array(new_vectors)

# %%
# most common words
restrict_embedd(embedd, ["'s", "''"])
NWORDS=len(embedd)
N = 50
print(f'The database contains (after pruning) {NWORDS} words.')
print(f'The {N} most common ones are: \n')
for index, word in enumerate(w1.index_to_key):
    if index == N:
        break
    print(f"word #{index}/{len(w1.index_to_key)} is {word}")
# Out:
# The database contains (after pruning) 399707 words.
# The 50 most common ones are:
#
# word #0/399706 is the
# word #1/399706 is of
# word #2/399706 is to
# word #3/399706 is and
# word #4/399706 is in
# word #5/399706 is for
# word #6/399706 is that
# word #7/399706 is on
# word #8/399706 is is
# word #9/399706 is was
# word #10/399706 is said
# word #11/399706 is with
# word #12/399706 is he
# word #13/399706 is as
# word #14/399706 is it
# word #15/399706 is by
# word #16/399706 is at
# word #17/399706 is from
# word #18/399706 is his
# word #19/399706 is an
# word #20/399706 is be
# word #21/399706 is has
# word #22/399706 is are
# word #23/399706 is have
# word #24/399706 is but
# word #25/399706 is were
# word #26/399706 is not
# word #27/399706 is this
# word #28/399706 is who
# word #29/399706 is they
# word #30/399706 is had
# word #31/399706 is which
# word #32/399706 is will
# word #33/399706 is their
# word #34/399706 is or
# word #35/399706 is its
# word #36/399706 is one
# word #37/399706 is after
# word #38/399706 is new
# word #39/399706 is been
# word #40/399706 is also
# word #41/399706 is we
# word #42/399706 is would
# word #43/399706 is two
# word #44/399706 is more
# word #45/399706 is first
# word #46/399706 is about
# word #47/399706 is up
# word #48/399706 is when
# word #49/399706 is year

# %% [markdown]
# ## Cosine similarity, most similar words

# %%
# look at some vectors

# %%
king = embedd['king']; king
# Out:
# array([ 0.50451 ,  0.68607 , -0.59517 , -0.022801,  0.60046 , -0.13498 ,
#        -0.08813 ,  0.47377 , -0.61798 , -0.31012 , -0.076666,  1.493   ,
#        -0.034189, -0.98173 ,  0.68229 ,  0.81722 , -0.51874 , -0.31503 ,
#        -0.55809 ,  0.66421 ,  0.1961  , -0.13495 , -0.11476 , -0.30344 ,
#         0.41177 , -2.223   , -1.0756  , -1.0783  , -0.34354 ,  0.33505 ,
#         1.9927  , -0.04234 , -0.64319 ,  0.71125 ,  0.49159 ,  0.16754 ,
#         0.34344 , -0.25663 , -0.8523  ,  0.1661  ,  0.40102 ,  1.1685  ,
#        -1.0137  , -0.21585 , -0.15155 ,  0.78321 , -0.91241 , -1.6106  ,
#        -0.64426 , -0.51042 ], dtype=float32)

# %%
queen = embedd['queen']; queen
# Out:
# array([ 0.37854  ,  1.8233   , -1.2648   , -0.1043   ,  0.35829  ,
#         0.60029  , -0.17538  ,  0.83767  , -0.056798 , -0.75795  ,
#         0.22681  ,  0.98587  ,  0.60587  , -0.31419  ,  0.28877  ,
#         0.56013  , -0.77456  ,  0.071421 , -0.5741   ,  0.21342  ,
#         0.57674  ,  0.3868   , -0.12574  ,  0.28012  ,  0.28135  ,
#        -1.8053   , -1.0421   , -0.19255  , -0.55375  , -0.054526 ,
#         1.5574   ,  0.39296  , -0.2475   ,  0.34251  ,  0.45365  ,
#         0.16237  ,  0.52464  , -0.070272 , -0.83744  , -1.0326   ,
#         0.45946  ,  0.25302  , -0.17837  , -0.73398  , -0.20025  ,
#         0.2347   , -0.56095  , -2.2839   ,  0.0092753, -0.60284  ],
#       dtype=float32)

# %%
# What is the female counterpart of a king?
embedd.most_similar(positive=['king', 'woman'], 
                             negative=['man'])
# Out:
# [('queen', 0.8523604273796082),
#  ('throne', 0.7664334177970886),
#  ('prince', 0.7592144012451172),
#  ('daughter', 0.7473883628845215),
#  ('elizabeth', 0.7460219860076904),
#  ('princess', 0.7424570322036743),
#  ('kingdom', 0.7337412238121033),
#  ('monarch', 0.721449077129364),
#  ('eldest', 0.7184861898422241),
#  ('widow', 0.7099431157112122)]

# %%
# What is the female counterpart of a king?
embedd.most_similar(positive=['king', 'she'], 
                             negative=['he'])
# Out:
# [('queen', 0.879991352558136),
#  ('princess', 0.8010349869728088),
#  ('daughter', 0.7692949771881104),
#  ('elizabeth', 0.767657458782196),
#  ('prince', 0.7667238116264343),
#  ('uncle', 0.738310694694519),
#  ('mother', 0.7349600791931152),
#  ('aunt', 0.7316499352455139),
#  ('son', 0.7305317521095276),
#  ('lady', 0.7275319695472717)]

# %%
embedd.most_similar(positive=['doctor', 'she'], 
                             negative=['he'])
# Out:
# [('nurse', 0.8434410095214844),
#  ('mother', 0.7978049516677856),
#  ('child', 0.7920326590538025),
#  ('woman', 0.7831878066062927),
#  ('pregnant', 0.7726936936378479),
#  ('girl', 0.7672077417373657),
#  ('her', 0.7481821775436401),
#  ('patient', 0.7464373707771301),
#  ('boy', 0.7313278913497925),
#  ('learns', 0.7268911600112915)]

# %%
def cos_sim(u, v):
    return np.inner(u,v)/math.sqrt(np.inner(u,u)*np.inner(v,v))

# %%
# project on this axis for gender bias
he = embedd['he']; she = embedd['she'] ; gbias = he - she; gbias
# Out:
# array([-0.261302  , -0.438481  ,  0.13376004, -0.12281001, -0.00838   ,
#        -0.64455   , -0.13150996, -0.01198   , -0.73557   ,  0.04754001,
#         0.04260999,  0.23386998, -0.56951   , -0.24359   , -0.29471004,
#        -0.152461  ,  0.44637996, -0.08563   , -0.66735   ,  0.20257801,
#        -0.28133   , -0.71557   , -0.04014999, -0.42204   , -0.63574   ,
#        -0.11930013,  0.429694  , -0.216301  , -0.08826   ,  0.5115    ,
#         0.28599977, -0.227249  , -0.25811   , -0.18074998,  0.22733   ,
#         0.15184401,  0.13196   ,  0.14411998, -0.01708999,  0.62810004,
#        -0.124465  ,  0.16902   , -0.62446666,  0.53734   , -0.379254  ,
#         0.3373    , -0.38487598,  0.92383   ,  0.019064  , -0.435641  ],
#       dtype=float32)

# %%
doctor = embedd['doctor']
sim = embedd.most_similar(positive=['doctor'], 
                             negative=[])
for li in sim:
    word = li[0]
    print(f'{word} is {cos_sim(doctor,embedd[word])} similar to doctor.')
# Out:
# nurse is 0.7977496777647489 similar to doctor.
# physician is 0.7965211591055051 similar to doctor.
# patient is 0.7611691340228203 similar to doctor.
# child is 0.755893738561101 similar to doctor.
# teacher is 0.7538283512557397 similar to doctor.
# surgeon is 0.7479071795905597 similar to doctor.
# psychiatrist is 0.7422092756716652 similar to doctor.
# doctors is 0.7393607058950945 similar to doctor.
# father is 0.7334106401611019 similar to doctor.
# mother is 0.7284410435938768 similar to doctor.

# %% [markdown]
# ## Genderdness for words

# %%
def genderness(word):
    return cos_sim(embedd[word], embedd['he'] - embedd['she'])

# %%
[genderness(_) for _ in ['he', 'man', 'king', 'beard']]
# Out:
# [0.17669018921772683,
#  -0.0759546247262612,
#  0.11793255256397168,
#  -0.2758265858843089]

# %%
[genderness(_) for _ in ['she', 'woman', 'queen', 'pink']]
# Out:
# [-0.3014023502580305,
#  -0.4019534575008965,
#  -0.3114308307117062,
#  -0.30173915446792415]

# %%
N = 5
glist = [ (word, genderness(word)) for index, word in enumerate(embedd.index_to_key)]
glist[:N]
# Out:
# [('the', 0.2157683615819542),
#  ('of', 0.1376989176026331),
#  ('to', 0.12531179022375147),
#  ('and', 0.05365547233778015),
#  ('in', 0.1617873422279208),
#  ('for', 0.16328029162213278),
#  ('that', 0.11938295904977994),
#  ('on', 0.11779737644387789),
#  ('is', 0.02644704568364468),
#  ('was', 0.20107389690457217),
#  ('said', 0.0858675131161634),
#  ('with', 0.11936578274714116),
#  ('he', 0.17669018921772683),
#  ('as', 0.1472170890823175),
#  ('it', 0.06459969309715238),
#  ('by', 0.2084396689938298),
#  ('at', 0.12464367188909856),
#  ('from', 0.1576068399395845),
#  ('his', 0.09822473024601373),
#  ('``', -0.08239010914021458),
#  ('an', 0.15313326221407683),
#  ('be', 0.14281397461179113),
#  ('has', 0.18537651771997568),
#  ('are', 0.08518822951691048),
#  ('have', 0.1824187848947825),
#  ('but', 0.15283295723855167),
#  ('were', 0.21043096810240325),
#  ('not', 0.1264520110701693),
#  ('this', 0.11192121932386376),
#  ('who', 0.09413458446152134),
#  ('they', 0.09642029331262691),
#  ('had', 0.22993484808266867),
#  ('which', 0.13931202423453307),
#  ('will', 0.08094832764718458),
#  ('their', 0.06658356411481653),
#  ('or', 0.003528258874162066),
#  ('its', 0.14503302130461215),
#  ('one', 0.09700918577559754),
#  ('after', 0.2193752307818039),
#  ('new', 0.11454181036094088),
#  ('been', 0.21053292398404477),
#  ('also', 0.16313454825196658),
#  ('we', 0.06678851839068867),
#  ('would', 0.14329251458300726),
#  ('two', 0.18151743335204432),
#  ('more', 0.05743258135939494),
#  ('first', 0.18992241928137363),
#  ('about', 0.01347564033198314),
#  ('up', 0.05104211009369941),
#  ('when', 0.14549987589341296)]

# %%
sglist = sorted(glist, key=lambda foo: foo[1])
# Out:
# [('mulleavy', -0.7006985315544474),
#  ('darrieussecq', -0.6763547061645346),
#  ('mandrell', -0.675704004621733),
#  ('monheit', -0.668710296489365),
#  ('mehretu', -0.6631638297738612),
#  ('wiedlin', -0.648022452907506),
#  ('streb', -0.6446613680196839),
#  ('medrich', -0.6427991526776876),
#  ('mcgarrigle', -0.6426385625417351),
#  ('herdahl', -0.6382342004626715)]

# %%
# most female words
N = 75
sglist[:N]
# Out:
# [('mulleavy', -0.7006985315544474),
#  ('darrieussecq', -0.6763547061645346),
#  ('mandrell', -0.675704004621733),
#  ('monheit', -0.668710296489365),
#  ('mehretu', -0.6631638297738612),
#  ('wiedlin', -0.648022452907506),
#  ('streb', -0.6446613680196839),
#  ('medrich', -0.6427991526776876),
#  ('mcgarrigle', -0.6426385625417351),
#  ('herdahl', -0.6382342004626715),
#  ('fozzard', -0.6321265907192541),
#  ('miscarries', -0.6317290736688587),
#  ('pavlova', -0.6313723975012049),
#  ('arkhipova', -0.6232624127449452),
#  ('schorpen', -0.6220365711602908),
#  ('kuppinger', -0.6218319863919527),
#  ('voluptuous', -0.6156876496819695),
#  ('lactating', -0.6144926237812198),
#  ('siberry', -0.6115365967594316),
#  ('anle', -0.6105483085820074),
#  ('ivanovna', -0.6104895752796777),
#  ('melua', -0.6072749017493507),
#  ('hollaback', -0.6072176443341113),
#  ('mononoke', -0.6066046005672917),
#  ('meiselas', -0.6055032264273342),
#  ('cutrufello', -0.6029877730267844),
#  ('clabber', -0.6005202080920384),
#  ('annie', -0.5996489224384548),
#  ('marling', -0.5988145224790686),
#  ('quindlen', -0.598297967306908),
#  ('lapotaire', -0.5979847552422775),
#  ('boldrini', -0.5973118607585864),
#  ('pavord', -0.597091741184199),
#  ('oresme', -0.594191682313611),
#  ('branigan', -0.5938675592085423),
#  ('latifah', -0.5937336678374425),
#  ('nyro', -0.5935203136284221),
#  ('prejean', -0.5930316441558333),
#  ('koplowitz', -0.5927782275415705),
#  ('holofcener', -0.5916740364141801),
#  ('likelike', -0.5912286260420666),
#  ('sebold', -0.5889731081200563),
#  ('rinna', -0.5889487997180471),
#  ('brownley', -0.5885161448890851),
#  ('yesipova', -0.5873065084063455),
#  ('erdrich', -0.5857974905945112),
#  ('gorgone', -0.5839058720750511),
#  ('netrebko', -0.5822937242712587),
#  ('scantily-clad', -0.5813240340564738),
#  ('sunee', -0.5810379052577503),
#  ('robelot', -0.5805054258216977),
#  ('oxeant', -0.5801749926542062),
#  ('casamassima', -0.579259593618371),
#  ('caraboo', -0.5792185697831099),
#  ('diva', -0.5784384442285196),
#  ('daulne', -0.5784186509776131),
#  ('beyoncé', -0.5783951144889163),
#  ('hattner', -0.5777847878058228),
#  ('rudner', -0.5776889631149994),
#  ('glaspell', -0.5773642044950701),
#  ('yolen', -0.5771062649674166),
#  ('emily', -0.5768535006549107),
#  ('maertha', -0.576669123758369),
#  ('pitzl', -0.5752142347926938),
#  ('trixie', -0.5750263763446851),
#  ('dreamboat', -0.5749555673477175),
#  ('charren', -0.5745100563037902),
#  ('yuskavage', -0.5736047150869238),
#  ('brownmiller', -0.5730179700009116),
#  ('numeroff', -0.5723473861203943),
#  ('p!nk', -0.5710170407774171),
#  ('aspey', -0.5705132739543279),
#  ('fiona', -0.5701632920657684),
#  ('byrn', -0.5700491345484734),
#  ('sister-ships', -0.5696561218598176)]

# %%
# male words
sglist[-N:]
# Out:
# [('steelers', 0.4704709081323434),
#  ('td', 0.47119263111271936),
#  ('covenanter', 0.47133804758514075),
#  ('sonics', 0.47198366388873),
#  ('delian', 0.4735424873119514),
#  ('huskers', 0.4736557286893722),
#  ('rangers', 0.4752321334018177),
#  ('bucs', 0.4772416789451398),
#  ('sack', 0.4774244724680948),
#  ('amphictyonic', 0.47805485546101123),
#  ('formio', 0.47820421078111597),
#  ('colts', 0.47845576084601854),
#  ('pro-treaty', 0.4787262327607465),
#  ('20-horse', 0.47882021722643786),
#  ('cgt', 0.4789646647673948),
#  ('hvo', 0.48117312365712117),
#  ('fatimid', 0.4818402181782809),
#  ('ayyubids', 0.4823288988402379),
#  ('admirals', 0.48320431063103975),
#  ('anti-treaty', 0.4835090890078665),
#  ('defensive', 0.4837984833926378),
#  ('chargers', 0.4844255181893741),
#  ('keynes', 0.48443885465292086),
#  ('league', 0.4851302807257394),
#  ('nl', 0.4861177658894251),
#  ('timberwolves', 0.48759326611591153),
#  ('redskins', 0.48769608553607346),
#  ('browns', 0.4885224557680987),
#  ('pompey', 0.4891323664452952),
#  ('supersonics', 0.48959095939136477),
#  ('brees', 0.4902826120715378),
#  ('ejection', 0.4911356569067291),
#  ('abbasid', 0.4918407779855409),
#  ('no-hitter', 0.49218792633904046),
#  ('assemblymen', 0.49277687313707474),
#  ('pistons', 0.4945292220069899),
#  ('rra', 0.494752608599718),
#  ('pacers', 0.49674789571110894),
#  ('bengals', 0.49674970854430833),
#  ('re-organisation', 0.497187832500127),
#  ('putsch', 0.5009630163318942),
#  ('fdd', 0.5016592471371002),
#  ('divisional', 0.5035179360805694),
#  ('negated', 0.506570585679775),
#  ('kanu', 0.5070159216120671),
#  ('cardinals', 0.5099445169959584),
#  ('atomics', 0.5104268331925452),
#  ('sabean', 0.5108857314137624),
#  ('technicals', 0.5118385603738694),
#  ('latics', 0.5151405722388062),
#  ('amre', 0.517313858232836),
#  ('aetolian', 0.517465483732297),
#  ('umayyads', 0.5220122700441521),
#  ('seahawks', 0.522870468539588),
#  ('abdulsalami', 0.523063013046049),
#  ('ravens', 0.5279268148997815),
#  ('chiefs', 0.5319839976856588),
#  ('vikings', 0.5349593947721312),
#  ('anti-saloon', 0.5351950863743006),
#  ('electro-motive', 0.5418558900188718),
#  ('meraj', 0.5419924026601426),
#  ('buccaneers', 0.543431804296054),
#  ('kff', 0.5446281048742254),
#  ('umps', 0.5454923521640411),
#  ('colonels', 0.5488922891710101),
#  ('patriots', 0.5491432218893945),
#  ('caliphs', 0.549171601932912),
#  ('umayyad', 0.5581718293917093),
#  ('rashidun', 0.5610546569577152),
#  ('mamluk', 0.5667197965065496),
#  ('kassam', 0.5769511918573533),
#  ('sacked', 0.6105438352971417),
#  ('achaean', 0.6114421093899526),
#  ('gowon', 0.6116083962297205),
#  ('sacking', 0.6216723391079291)]

# %%
#cosine similarity between -1 and 1, opposite and equal
import math
N=20
gbiaslen = math.sqrt(np.inner(gbias,gbias))
for index, word in enumerate(wv.index_to_key):
    if index == N:
        break
    s= wv[word] 
    slen = math.sqrt(np.inner(s,s))
    cossim = np.inner(s,gbias)/(slen*gbiaslen)
    print(f"word #{index}: {word} \t cosine similarity: {cossim}")
# Out:
# word #0: <user> 	 cosine similarity: 0.315461347308407
# word #1: . 	 cosine similarity: 0.3120420296821631
# word #2: : 	 cosine similarity: 0.2021089266629955
# word #3: rt 	 cosine similarity: 0.22026941315765367
# word #4: , 	 cosine similarity: 0.3220862378587254
# word #5: <repeat> 	 cosine similarity: 0.3355283050941834
# word #6: <hashtag> 	 cosine similarity: 0.12100433169988391
# word #7: <number> 	 cosine similarity: 0.26522150675283335
# word #8: <url> 	 cosine similarity: 0.04085328944844525
# word #9: ! 	 cosine similarity: 0.39057435414272335
# word #10: i 	 cosine similarity: 0.22648235142697185
# word #11: a 	 cosine similarity: 0.20254158386314305
# word #12: " 	 cosine similarity: 0.2215016782956034
# word #13: the 	 cosine similarity: 0.01926590952395525
# word #14: ? 	 cosine similarity: 0.4114748918276393
# word #15: you 	 cosine similarity: 0.05096463796152975
# word #16: to 	 cosine similarity: 0.17384301211533448
# word #17: ( 	 cosine similarity: 0.07946246627724533
# word #18: <allcaps> 	 cosine similarity: 0.013350678342655933
# word #19: <elong> 	 cosine similarity: 0.4322308128550081

# %%
#correlation length of words to gender bias
N = NWORDS
gbiaslen = math.sqrt(np.inner(gbias,gbias))
len2bias = [] 
x = []
y = []
for index, word in enumerate(wv.index_to_key):
    if index == N:
        break
    s= wv[word] 
    slen = math.sqrt(np.inner(s,s))
    cossim = np.inner(s,gbias)/(slen*gbiaslen)
    wlen = len(word)
    len2bias.append((wlen,cossim))
    x.append(wlen)
    y.append(cossim)

# %%
x=np.array(x)
y=np.array(y)
A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y)[0]
# Out:
# /tmp/ipykernel_34005/3186300230.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, c = np.linalg.lstsq(A, y)[0]

# %%
m,c
# Out:
# (-0.0018242126934274274, -0.11283737378384415)

# %%
import matplotlib.pyplot as plt

_ = plt.plot(x, y, 'o', label='Original data', markersize=0.1)

_ = plt.plot(x, m*x + c, 'r', label=f'Fitted line y={m}x + {c} ')

_ = plt.legend()

plt.show()

# %%
#correlation frequence of words to gender bias

# %%
N = NWORDS
gbiaslen = math.sqrt(np.inner(gbias,gbias))
freq2bias = []
x = []
y = []
for index, word in enumerate(wv.index_to_key):
    if index == N:
        break
    s= wv[word] 
    slen = math.sqrt(np.inner(s,s))
    cossim = np.inner(s,gbias)/(slen*gbiaslen)
    wfreq = wv.get_vecattr(word, "count")/NWORDS  # returns count of "my-word"
    freq2bias.append((wfreq,cossim))
    x.append(wfreq)
    y.append(cossim)

# %%
x=np.array(x)
y=np.array(y)
A = np.vstack([x, np.ones(len(x))]).T
m, c = np.linalg.lstsq(A, y)[0]
# Out:
# /tmp/ipykernel_34005/3186300230.py:4: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   m, c = np.linalg.lstsq(A, y)[0]

# %%
m,c
# Out:
# (0.13979643280819515, -0.19501714389103456)

# %%
import matplotlib.pyplot as plt

_ = plt.plot(x, y, 'o', label='Original data', markersize=0.1)

_ = plt.plot(x, m*x + c, 'r', label='Fitted line')

_ = plt.legend()

plt.show()

# %%
#correlation length of words to gender bias
NWORDS=len(wv)
N = NWORDS
gbiaslen = math.sqrt(np.inner(gbias,gbias))
reslista = [] 
x = []
y = []
for index, word in enumerate(wv.index_to_key):
    if index == N:
        break
    s= wv[word] 
    slen = math.sqrt(np.inner(s,s))
    cossim = np.inner(s,gbias)/(slen*gbiaslen)
    wlen = len(word)
    reslista.append((cossim,word))
    x.append(word)
    y.append(cossim)


rsorted=sorted(reslista,key=lambda x: x[0])

print(rsorted[:40])
print()
print(rsorted[-40:])
# Out:
# [(-0.7762818646065502, 'solusicerdasku'), (-0.7389403337451002, '浩史'), (-0.7205547502266584, 'nhot'), (-0.7137885493051339, '規制垢のフォローもお願いします'), (-0.7115668684580332, 'فلوباكnn'), (-0.7055519988480086, 'r.o.d'), (-0.7016833265913816, 'hoot'), (-0.7011906813879232, '規制垢もよろしく'), (-0.7005161236396711, 'meow'), (-0.700182750465858, 'بصريه'), (-0.6998703174661799, 'u.n.オーエンは彼女なのか'), (-0.695636800738269, 'pouting'), (-0.6953539551638425, 'hugz'), (-0.6911564379100253, 'ホイホイチャーハン'), (-0.6879737524388297, 'ウホッアッー'), (-0.6878494659855363, 'latepost'), (-0.687616834904858, 'ciamatıni̇çki'), (-0.6872500005248535, 'アンビリーバボー怖いね'), (-0.686792662806807, '경고문'), (-0.6834641701904794, 'wеrе'), (-0.683319634838266, 'likeforlike'), (-0.6829712682638581, '義務なんです'), (-0.6798317677411416, 'フォーリンラブ'), (-0.6794318499888057, 'おっちん'), (-0.6790323624151069, '↛'), (-0.6786680659222168, '妄想垢'), (-0.6783057109582664, 'peasant'), (-0.676844771056863, '創作垢作りました'), (-0.6749231342060245, 'voicee'), (-0.6735167162021153, '#ابي'), (-0.6726513626561536, 'lovinn'), (-0.6720125924376994, 'havalimani'), (-0.6714701554176301, 'smokeys'), (-0.6711136270599685, 'มาคุยกันนะครับ'), (-0.6700733365301892, 'ᴘɪᴄ'), (-0.6699993058546972, 'nフォローしたら'), (-0.6695728497851658, '規制垢だよ'), (-0.669275438426442, '聞いてるの'), (-0.6692672805683423, 'مهآرة'), (-0.6691582196359205, 'チンチン')]
#
# [(0.7041444985308257, 'ambos'), (0.7049068370888537, 'costado'), (0.7057973667124836, 'haya'), (0.7072908502846357, 'sabido'), (0.7079361688435971, 'pasará'), (0.7086391567153847, 'sido'), (0.709057658043424, 'cambios'), (0.7111203122680627, 'superado'), (0.7117710921752305, 'serán'), (0.7122085022082398, 'partidos'), (0.7126754924020983, 'exactamente'), (0.7127100951481046, 'fallos'), (0.7135633415523599, 'lecciones'), (0.7136181292302408, 'peores'), (0.7148335395150732, 'consecuencias'), (0.7150800981867986, 'posibilidades'), (0.7154235208601185, 'incluso'), (0.7156445183401956, 'siglo'), (0.7162418458887126, 'habían'), (0.724154739156452, 'ganado'), (0.7251440420864559, 'quedan'), (0.7252020352530179, 'tiempo'), (0.7255059846873789, 'siglos'), (0.7255400925288714, 'hecho'), (0.726220511971328, 'difíciles'), (0.7274259039427556, 'ocurrido'), (0.7315187526855641, 'jugado'), (0.7333311142031479, 'ocasiones'), (0.7373550908579038, 'llegado'), (0.7384579504157402, 'hayan'), (0.7389353360985214, 'libres'), (0.741709431953946, 'principio'), (0.7440948347229914, 'habido'), (0.7464038014013081, 'tenido'), (0.7539053898332946, 'finales'), (0.7542691437455649, 'errores'), (0.7653378766926393, 'hemos'), (0.7824946603526838, 'tercero'), (0.7862334163824471, 'aprendido'), (0.7923642855011643, 'pasado')]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 2
#       1 s=gbias
# ----> 2 slen = math.sqrt(s.inner(s))
#       3 cossim = np.inner(s,gbias)/(slen*gbiaslen)
#       4 cossim
#
# AttributeError: 'numpy.ndarray' object has no attribute 'inner'

# %%
len(y)
# Out:
# 1193514

# %%
import matplotlib.pyplot as plt 
plt.hist(y, edgecolor="red", bins=20) 
plt.show()

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from '/home/jan/miniforge3/envs/sage/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
rsorted[-70:]
# Out:
# [(0.6847077701161269, 'sufrido'),
#  (0.6847846575177416, 'habiendo'),
#  (0.6858168439541826, 'principios'),
#  (0.686129459417209, 'haber'),
#  (0.6866030911867388, 'faltas'),
#  (0.6867052233594227, 'interés'),
#  (0.6870485321199252, 'mínimo'),
#  (0.6874277494810334, 'diferencias'),
#  (0.6877380595590759, 'cuartos'),
#  (0.6887078178543391, 'condiciones'),
#  (0.6901767204499716, 'aproximadamente'),
#  (0.6902932247563834, 'serían'),
#  (0.690571982031351, 'dejado'),
#  (0.691050298764655, 'habíamos'),
#  (0.6919618006119104, 'habrán'),
#  (0.6921790045249322, 'habrás'),
#  (0.6928044913741731, 'minuto'),
#  (0.6929190523707555, 'capaces'),
#  (0.6936442744721051, 'aún'),
#  (0.6939522634731219, 'habría'),
#  (0.6948160078661798, 'habrá'),
#  (0.6962291426252062, 'vivido'),
#  (0.6963912762692945, 'salido'),
#  (0.6969293405096483, 'hubieran'),
#  (0.6969800371344541, 'accidentes'),
#  (0.698459962683815, 'pasados'),
#  (0.6993368648705813, 'perdido'),
#  (0.7016163917791265, 'opciones'),
#  (0.7020229444030281, 'semanas'),
#  (0.7021307429539316, 'podido'),
#  (0.7041444985308257, 'ambos'),
#  (0.7049068370888537, 'costado'),
#  (0.7057973667124836, 'haya'),
#  (0.7072908502846357, 'sabido'),
#  (0.7079361688435971, 'pasará'),
#  (0.7086391567153847, 'sido'),
#  (0.709057658043424, 'cambios'),
#  (0.7111203122680627, 'superado'),
#  (0.7117710921752305, 'serán'),
#  (0.7122085022082398, 'partidos'),
#  (0.7126754924020983, 'exactamente'),
#  (0.7127100951481046, 'fallos'),
#  (0.7135633415523599, 'lecciones'),
#  (0.7136181292302408, 'peores'),
#  (0.7148335395150732, 'consecuencias'),
#  (0.7150800981867986, 'posibilidades'),
#  (0.7154235208601185, 'incluso'),
#  (0.7156445183401956, 'siglo'),
#  (0.7162418458887126, 'habían'),
#  (0.724154739156452, 'ganado'),
#  (0.7251440420864559, 'quedan'),
#  (0.7252020352530179, 'tiempo'),
#  (0.7255059846873789, 'siglos'),
#  (0.7255400925288714, 'hecho'),
#  (0.726220511971328, 'difíciles'),
#  (0.7274259039427556, 'ocurrido'),
#  (0.7315187526855641, 'jugado'),
#  (0.7333311142031479, 'ocasiones'),
#  (0.7373550908579038, 'llegado'),
#  (0.7384579504157402, 'hayan'),
#  (0.7389353360985214, 'libres'),
#  (0.741709431953946, 'principio'),
#  (0.7440948347229914, 'habido'),
#  (0.7464038014013081, 'tenido'),
#  (0.7539053898332946, 'finales'),
#  (0.7542691437455649, 'errores'),
#  (0.7653378766926393, 'hemos'),
#  (0.7824946603526838, 'tercero'),
#  (0.7862334163824471, 'aprendido'),
#  (0.7923642855011643, 'pasado')]
